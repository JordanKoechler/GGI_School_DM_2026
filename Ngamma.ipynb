# %%
from CosmiXs import annihilation_spectrum
from scipy.integrate import simpson

spec = annihilation_spectrum(100, 'b', 'Gamma', path='CosmiXs')
simpson(y=spec[:, 1], x=spec[:, 0])
# Out:
# 35.98588373174307
